# %% [markdown]
# # 从下到上查找，先查实例属性，再查类属性

# %%
class A:
    name = 'A'
    def __init__(self):
        self.name = 'obj'

a = A()
print(a.name)
# Out:
# obj

# %%
class A:
    name = 'A'

a = A()
print(a.name)
# Out:
# A

# %% [markdown]
# ## MRO算法
# DFS 深度优先搜索
#
# ![image.png](attachment:image.png)

# %% [markdown]
# python2 使用 BFS 广度优先算法
# ![image.png](attachment:image.png)

# %% [markdown]
# python3 使用C3算法
